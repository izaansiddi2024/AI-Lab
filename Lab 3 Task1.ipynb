# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np

# %%
# Creating the dataset based on the given table
data = {
    "Outlook": ["Sunny", "Sunny", "Overcast", "Rainy", "Rainy", "Rainy", "Overcast", 
                "Sunny", "Sunny", "Rainy", "Sunny", "Overcast", "Overcast", "Rainy"],
    "Temperature": ["Hot", "Hot", "Hot", "Mild", "Cool", "Cool", "Cool", 
                    "Mild", "Cool", "Mild", "Mild", "Mild", "Hot", "Mild"],
    "Play": ["No", "No", "Yes", "Yes", "Yes", "No", "Yes", 
             "No", "Yes", "Yes", "Yes", "Yes", "Yes", "No"]
}

df = pd.DataFrame(data)

# %%
# Encoding categorical features
df['Outlook'] = df['Outlook'].map({"Sunny": 0, "Overcast": 1, "Rainy": 2})
df['Temperature'] = df['Temperature'].map({"Hot": 0, "Mild": 1, "Cool": 2})
df['Play'] = df['Play'].map({"No": 0, "Yes": 1})

# %%
# Splitting data into features and labels
X = df[['Outlook', 'Temperature']]
y = df['Play']

# %%
# Applying KNN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predicting for "Overcast" and "Mild" conditions
test_input = pd.DataFrame([[1, 1]], columns=['Outlook', 'Temperature'])  # Adding column names
prediction = knn.predict(test_input)

print("Prediction (0 = No, 1 = Yes):", prediction[0])
# Out:
# Prediction (0 = No, 1 = Yes): 1
